# %% [markdown]
# ##### Aufgabe 7:

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("mcycle.csv")

# %%
df
# Out:
#      times  accel
# 0      2.4    0.0
# 1      2.6   -1.3
# 2      3.2   -2.7
# 3      3.6    0.0
# 4      4.0   -2.7
# ..     ...    ...
# 128   53.2  -14.7
# 129   55.0   -2.7
# 130   55.0   10.7
# 131   55.4   -2.7
# 132   57.6   10.7
#
# [133 rows x 2 columns]

# %%
from sklearn import linear_model
from sklearn import tree
import matplotlib.pyplot as plt

# %%
# Linear Regression
X=df[["times"]]
y=df["accel"]
lin_reg=linear_model.LinearRegression()
lin_reg.fit(X,y)
# Out:
# LinearRegression()

# %%
# Decision Tree Regressor
tree_reg=tree.DecisionTreeRegressor()
tree_reg.fit(X,y)
# Out:
# DecisionTreeRegressor()

# %%
time_range=pd.DataFrame(np.linspace(X.min(),X.max(),100),columns=["times"])
time_range
# Out:
#         times
# 0    2.400000
# 1    2.957576
# 2    3.515152
# 3    4.072727
# 4    4.630303
# ..        ...
# 95  55.369697
# 96  55.927273
# 97  56.484848
# 98  57.042424
# 99  57.600000
#
# [100 rows x 1 columns]

# %%
plt.xlabel("times")
plt.ylabel("accel")
plt.scatter(X,y,color="black")
plt.plot(time_range,lin_reg.predict(time_range),color="red",label="Lineare Regression")
plt.plot(time_range,tree_reg.predict(time_range),color="green",label=" Regressionbaum")
plt.legend()
plt.show()

# %%
# Evaluation

# %% [markdown]
# #### Aufgabe 8:

# %%
import matplotlib.pyplot as plt
import sklearn.datasets as skd

X, y = skd.make_moons(
    n_samples = 1000,
    noise = 0.2,
    random_state = 42
)

plt.scatter(*X.T, c=y,s=8,cmap=plt.cm.Spectral)
plt.ylabel(r'$x_2$')
plt.xlabel(r'$x_1$')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
# Logistic Regression
log_reg=LogisticRegression()
log_reg.fit(X,y)
# Out:
# LogisticRegression()

# %%
# Klassificationbaum
cls_baum=DecisionTreeClassifier()
cls_baum.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
# Define Plotting ranges
x1_min=X[:,0].min()
x1_max=X[:,0].max()
x2_min=X[:,1].min()
x2_max=X[:,1].max()
